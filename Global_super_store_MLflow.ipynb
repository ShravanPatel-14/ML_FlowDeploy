# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\sanja\OneDrive\Attachments\Desktop\Datasets@ML\Global Superstore.xls")
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# 1        JR-16210     Justin Ritter    Corporate     Wollongong
# 2        CR-12730      Craig Reiter     Consumer       Brisbane
# 3        KM-16375  Katherine Murray  Home Office         Berlin
# 4         RH-9495       Rick Hansen     Consumer          Dakar
# ...           ...               ...          ...            ...
# 51285    KE-16420   Katrina Edelman    Corporate           Kure
# 51286    ZC-21910  Zuschuss Carroll     Consumer        Houston
# 51287    LB-16795    Laurel Beltran  Home Office         Oxnard
# 51288    RB-19795        Ross Baird  Home Office       Valinhos
# 51289    MC-18100     Mick Crebagga     Consumer       Tipitapa
#
#                  State  ...        Product ID         Category Sub-Category  \
# 0             New York  ...   TEC-AC-10003033       Technology  Accessories
# 1      New South Wales  ...   FUR-CH-10003950        Furniture       Chairs
# 2           Queensland  ...   TEC-PH-10004664       Technology       Phones
# 3               Berlin  ...   TEC-PH-10004583       Technology       Phones
# 4                Dakar  ...  TEC-SHA-10000501       Technology      Copiers
# ...                ...  ...               ...              ...          ...
# 51285        Hiroshima  ...   OFF-FA-10000746  Office Supplies    Fasteners
# 51286            Texas  ...   OFF-AP-10002906  Office Supplies   Appliances
# 51287       California  ...   OFF-EN-10001219  Office Supplies    Envelopes
# 51288        São Paulo  ...   OFF-BI-10000806  Office Supplies      Binders
# 51289          Managua  ...   OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit  Shipping Cost  Order Priority
# 0          0.0  762.1845        933.570        Critical
# 1          0.1 -288.7650        923.630        Critical
# 2          0.1  919.9710        915.490          Medium
# 3          0.1  -96.5400        910.160          Medium
# 4          0.0  311.5200        903.040        Critical
# ...        ...       ...            ...             ...
# 51285      0.0    4.5000          0.010          Medium
# 51286      0.8   -1.1100          0.010          Medium
# 51287      0.0   11.2308          0.010            High
# 51288      0.0    2.4000          0.003          Medium
# 51289      0.0    1.8000          0.002            High
#
# [51290 rows x 24 columns]

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.drop("Postal Code",axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          51290  51290.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528    246.490581      3.476545
# min              2011-01-03 00:00:00      0.444000      1.000000
# 25%              2012-06-23 00:00:00     30.758625      2.000000
# 50%              2013-07-12 00:00:00     85.053000      3.000000
# 75%              2014-05-26 00:00:00    251.053200      5.000000
# max              2015-01-07 00:00:00  22638.480000     14.000000
# std                              NaN    487.565361      2.278766
#
#            Discount        Profit  Shipping Cost
# count  51290.000000  51290.000000   51290.000000
# mean       0.142908     28.610982      26.375818
# min        0.000000  -6599.978000       0.002000
# 25%        0.000000      0.000000       2.610000
# 50%        0.000000      9.240000       7.790000
# 75%        0.200000     36.810000      24.450000
# max        0.850000   8399.976000     933.570000
# std        0.212280    174.340972      57.296810

# %%
for i in df.select_dtypes(include="number"):
    plt.figure()
    sns.boxplot(x=i,data=df)
    plt.show()

# %%
df["Profit"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     -30.5712
# 0.25       0.0000
# 0.50       9.2400
# 0.75      36.8100
# 1.00    8399.9760
# Name: Profit, dtype: float64

# %%
df.shape
# Out:
# (51290, 23)

# %%
df_1=df[(df["Profit"]>=0.0)&(df["Profit"]<=36.8100)]

# %%
df_1
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 18      22096    IN-2014-11763 2014-01-31 2014-02-01     First Class
# 89      26669    IN-2013-69730 2013-12-12 2013-12-14     First Class
# 99      18307  ES-2013-3903130 2013-09-03 2013-09-05    Second Class
# 152     18899  ES-2011-1426891 2011-09-20 2011-09-22    Second Class
# 200     24361    IN-2013-48184 2013-06-10 2013-06-10        Same Day
# ...       ...              ...        ...        ...             ...
# 51284   24175    IN-2014-57662 2014-08-05 2014-08-10  Standard Class
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID      Customer Name      Segment        City  \
# 18       JS-15685           Jim Sink    Corporate  Townsville
# 89       JM-15250       Janet Martin     Consumer      Suzhou
# 99       MZ-17335      Maria Zettner  Home Office    Malakoff
# 152      DB-13060        Dave Brooks     Consumer      Bochum
# 200      NM-18445       Nathan Mautz  Home Office    Shenzhen
# ...           ...                ...          ...         ...
# 51284    DB-13270  Deborah Brumfield  Home Office  Townsville
# 51285    KE-16420    Katrina Edelman    Corporate        Kure
# 51287    LB-16795     Laurel Beltran  Home Office      Oxnard
# 51288    RB-19795         Ross Baird  Home Office    Valinhos
# 51289    MC-18100      Mick Crebagga     Consumer    Tipitapa
#
#                         State  ...       Product ID         Category  \
# 18                 Queensland  ...  TEC-CO-10000865       Technology
# 89                      Anhui  ...  TEC-CO-10003102       Technology
# 99              Ile-de-France  ...  OFF-AP-10002904  Office Supplies
# 152    North Rhine-Westphalia  ...  TEC-CO-10004365       Technology
# 200                 Guangdong  ...  TEC-CO-10003819       Technology
# ...                       ...  ...              ...              ...
# 51284              Queensland  ...  OFF-BI-10002424  Office Supplies
# 51285               Hiroshima  ...  OFF-FA-10000746  Office Supplies
# 51287              California  ...  OFF-EN-10001219  Office Supplies
# 51288               São Paulo  ...  OFF-BI-10000806  Office Supplies
# 51289                 Managua  ...  OFF-PA-10004155  Office Supplies
#
#       Sub-Category                                  Product Name     Sales  \
# 18         Copiers               Brother Fax Machine, High-Speed  2565.594
# 89         Copiers                     Canon Copy Machine, Color  1581.480
# 99      Appliances           Hamilton Beach Refrigerator, Silver  3155.544
# 152        Copiers                        HP Wireless Fax, Color  3616.500
# 200        Copiers                Sharp Copy Machine, High-Speed   957.600
# ...            ...                                           ...       ...
# 51284      Binders                         Avery Binder, Economy    58.050
# 51285    Fasteners                 Advantus Thumb Tacks, 12 Pack    65.100
# 51287    Envelopes  #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920
# 51288      Binders                       Acco Index Tab, Economy    13.440
# 51289        Paper       Eaton Computer Printout Paper, 8.5 x 11    61.380
#
#       Quantity Discount   Profit  Shipping Cost  Order Priority
# 18           9      0.1  28.4040        766.930        Critical
# 89           6      0.0   0.0000        550.740            High
# 99           7      0.1  34.9440        539.940            High
# 152         10      0.0  36.0000        471.920        Critical
# 200          4      0.0   0.0000        427.100        Critical
# ...        ...      ...      ...            ...             ...
# 51284        5      0.1  19.9500          0.010          Medium
# 51285        5      0.0   4.5000          0.010          Medium
# 51287        3      0.0  11.2308          0.010            High
# 51288        2      0.0   2.4000          0.003          Medium
# 51289        3      0.0   1.8000          0.002            High
#
# [25928 rows x 23 columns]

# %%
df_1.shape
# Out:
# (25928, 23)

# %%
plt.boxplot(df_1["Profit"])
plt.show()

# %%
plt.boxplot(df_1["Sales"])
plt.show()

# %%
df_1["Sales"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10      12.54
# 0.25      23.64
# 0.50      48.78
# 0.75      96.18
# 1.00    3616.50
# Name: Sales, dtype: float64

# %%
df_f=df_1[(df_1["Sales"] >=23.64) & (df_1["Sales"] <=96.18)]

# %%
df_f
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 7223    47074     IZ-2013-2620 2013-11-26 2013-11-29     First Class
# 8190    13351  ES-2014-4622860 2014-06-09 2014-06-12     First Class
# 8217    21037    IN-2014-57011 2014-04-11 2014-04-14    Second Class
# 8474     3201   MX-2014-111234 2014-10-28 2014-10-28        Same Day
# 8630     6388   MX-2012-136287 2012-05-07 2012-05-10     First Class
# ...       ...              ...        ...        ...             ...
# 51281    6039   MX-2014-169530 2014-06-09 2014-06-11     First Class
# 51283   24105    IN-2014-72327 2014-05-30 2014-05-30        Same Day
# 51284   24175    IN-2014-57662 2014-08-05 2014-08-10  Standard Class
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID      Customer Name      Segment               City  \
# 7223     SO-10335     Sean O'Donnell     Consumer            Baghdad
# 8190     DB-13210        Dean Braden     Consumer             London
# 8217     JS-15685           Jim Sink    Corporate           Shanghai
# 8474     PV-18985      Paul Van Hugh  Home Office             Franca
# 8630     KD-16615           Ken Dana    Corporate          Carrefour
# ...           ...                ...          ...                ...
# 51281    HG-15025      Hunter Glantz     Consumer  Bragança Paulista
# 51283    KH-16330    Katharine Harms    Corporate            Lucknow
# 51284    DB-13270  Deborah Brumfield  Home Office         Townsville
# 51285    KE-16420    Katrina Edelman    Corporate               Kure
# 51289    MC-18100      Mick Crebagga     Consumer           Tipitapa
#
#                State  ...        Product ID         Category Sub-Category  \
# 7223         Baghdad  ...  OFF-STI-10001651  Office Supplies     Supplies
# 8190         England  ...   OFF-LA-10004280  Office Supplies       Labels
# 8217        Shanghai  ...   FUR-CH-10002412        Furniture       Chairs
# 8474       São Paulo  ...   OFF-SU-10002993  Office Supplies     Supplies
# 8630           Ouest  ...   TEC-PH-10004184       Technology       Phones
# ...              ...  ...               ...              ...          ...
# 51281      São Paulo  ...   OFF-PA-10002418  Office Supplies        Paper
# 51283  Uttar Pradesh  ...   OFF-PA-10000215  Office Supplies        Paper
# 51284     Queensland  ...   OFF-BI-10002424  Office Supplies      Binders
# 51285      Hiroshima  ...   OFF-FA-10000746  Office Supplies    Fasteners
# 51289        Managua  ...   OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name   Sales Quantity  \
# 7223                              Stiletto Shears, Steel  94.980        2
# 8190   Harbour Creations Legal Exhibit Labels, Alphab...  87.237        9
# 8217                               Hon Bag Chairs, Black  85.440        2
# 8474                         Fiskars Trimmer, High Speed  84.600        3
# 8630                    Motorola Headset, with Caller ID  95.688        3
# ...                                                  ...     ...      ...
# 51281                Green Bar Message Books, Multicolor  84.000        5
# 51283                     Eaton Parchment Paper, Premium  26.940        2
# 51284                              Avery Binder, Economy  58.050        5
# 51285                      Advantus Thumb Tacks, 12 Pack  65.100        5
# 51289            Eaton Computer Printout Paper, 8.5 x 11  61.380        3
#
#       Discount  Profit  Shipping Cost  Order Priority
# 7223       0.0   8.520         47.280        Critical
# 8190       0.1  31.887         41.270        Critical
# 8217       0.0   0.840         41.130        Critical
# 8474       0.0   6.720         39.813        Critical
# 8630       0.4  14.328         39.020        Critical
# ...        ...     ...            ...             ...
# 51281      0.0   9.200          0.019            High
# 51283      0.0   1.860          0.010            High
# 51284      0.1  19.950          0.010          Medium
# 51285      0.0   4.500          0.010          Medium
# 51289      0.0   1.800          0.002            High
#
# [12977 rows x 23 columns]

# %%
df_f.shape
# Out:
# (12977, 23)

# %%
plt.boxplot(df_f["Sales"])
plt.show()

# %%
plt.boxplot(df_f["Quantity"])
plt.show()

# %%
df_f["Quantity"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     1.0
# 0.25     2.0
# 0.50     3.0
# 0.75     4.0
# 1.00    14.0
# Name: Quantity, dtype: float64

# %%
df_3=df_f[(df_f["Quantity"] >= 2.0) & (df_f["Quantity"]<=4.0)]

# %%
df_3
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7223    47074    IZ-2013-2620 2013-11-26 2013-11-29     First Class
# 8217    21037   IN-2014-57011 2014-04-11 2014-04-14    Second Class
# 8474     3201  MX-2014-111234 2014-10-28 2014-10-28        Same Day
# 8630     6388  MX-2012-136287 2012-05-07 2012-05-10     First Class
# 8999     5959  MX-2012-104423 2012-10-05 2012-10-08     First Class
# ...       ...             ...        ...        ...             ...
# 51263    6367  MX-2011-131688 2011-12-22 2011-12-26  Standard Class
# 51266   22589   IN-2014-32000 2014-11-25 2014-11-30  Standard Class
# 51268   34657  US-2012-142020 2012-06-04 2012-06-08    Second Class
# 51283   24105   IN-2014-72327 2014-05-30 2014-05-30        Same Day
# 51289    6147  MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID       Customer Name      Segment           City  \
# 7223     SO-10335      Sean O'Donnell     Consumer        Baghdad
# 8217     JS-15685            Jim Sink    Corporate       Shanghai
# 8474     PV-18985       Paul Van Hugh  Home Office         Franca
# 8630     KD-16615            Ken Dana    Corporate      Carrefour
# 8999     RB-19360        Raymond Buch     Consumer       Coyoacán
# ...           ...                 ...          ...            ...
# 51263    BP-11230  Benjamin Patterson     Consumer         Toluca
# 51266    AO-10810   Anthony O'Donnell    Corporate          Perth
# 51268    TC-21535       Tracy Collins  Home Office  New York City
# 51283    KH-16330     Katharine Harms    Corporate        Lucknow
# 51289    MC-18100       Mick Crebagga     Consumer       Tipitapa
#
#                    State  ...        Product ID         Category Sub-Category  \
# 7223             Baghdad  ...  OFF-STI-10001651  Office Supplies     Supplies
# 8217            Shanghai  ...   FUR-CH-10002412        Furniture       Chairs
# 8474           São Paulo  ...   OFF-SU-10002993  Office Supplies     Supplies
# 8630               Ouest  ...   TEC-PH-10004184       Technology       Phones
# 8999    Distrito Federal  ...   OFF-SU-10004361  Office Supplies     Supplies
# ...                  ...  ...               ...              ...          ...
# 51263             México  ...   OFF-BI-10002799  Office Supplies      Binders
# 51266  Western Australia  ...   OFF-EN-10004941  Office Supplies    Envelopes
# 51268           New York  ...   OFF-PA-10004569  Office Supplies        Paper
# 51283      Uttar Pradesh  ...   OFF-PA-10000215  Office Supplies        Paper
# 51289            Managua  ...   OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name   Sales Quantity  \
# 7223                              Stiletto Shears, Steel  94.980        2
# 8217                               Hon Bag Chairs, Black  85.440        2
# 8474                         Fiskars Trimmer, High Speed  84.600        3
# 8630                    Motorola Headset, with Caller ID  95.688        3
# 8999                        Kleencut Trimmer, High Speed  82.860        3
# ...                                                  ...     ...      ...
# 51263                       Acco Binder Covers, Recycled  36.480        4
# 51266                GlobeWeis Manila Envelope, Recycled  47.142        2
# 51268  Wirebound Message Books, Two 4 1/4" x 5" Forms...  30.440        4
# 51283                     Eaton Parchment Paper, Premium  26.940        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11  61.380        3
#
#       Discount   Profit  Shipping Cost  Order Priority
# 7223       0.0   8.5200         47.280        Critical
# 8217       0.0   0.8400         41.130        Critical
# 8474       0.0   6.7200         39.813        Critical
# 8630       0.4  14.3280         39.020        Critical
# 8999       0.0  16.5600         37.298        Critical
# ...        ...      ...            ...             ...
# 51263      0.0   3.2800          0.039          Medium
# 51266      0.1   8.8620          0.030          Medium
# 51268      0.0  14.3068          0.030          Medium
# 51283      0.0   1.8600          0.010            High
# 51289      0.0   1.8000          0.002            High
#
# [7906 rows x 23 columns]

# %%
df_3.shape
# Out:
# (7906, 23)

# %%
plt.boxplot(df_3["Quantity"])
plt.show()

# %%
plt.boxplot(df_3["Shipping Cost"])
plt.show()

# %%
df_3["Shipping Cost"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     1.72000
# 0.25     2.70000
# 0.50     4.46100
# 0.75     7.23675
# 1.00    47.28000
# Name: Shipping Cost, dtype: float64

# %%
df_4=df_3[(df_3["Shipping Cost"] >=2.70) & (df_3["Shipping Cost"] <=7.23675)]

# %%
df_4.shape
# Out:
# (3953, 23)

# %%
plt.boxplot(df_4["Shipping Cost"])
plt.show()

# %%
df_4.head()
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 26583   10778  ES-2014-5617990 2014-09-11 2014-09-12     First Class
# 26584   17129  ES-2014-3096832 2014-07-04 2014-07-09  Standard Class
# 26586   21231    IN-2012-45951 2012-11-02 2012-11-06  Standard Class
# 26587   23945    IN-2012-40547 2012-11-29 2012-11-30     First Class
# 26594   31408   CA-2013-128867 2013-11-04 2013-11-11  Standard Class
#
#       Customer ID   Customer Name    Segment          City            State  \
# 26583    LW-16825  Laurel Workman  Corporate  Schiltigheim           Alsace
# 26584    BW-11065   Barry Weirich   Consumer       Catania           Sicily
# 26586    JG-15115      Jack Garza   Consumer        Bhopal   Madhya Pradesh
# 26587    GT-14710       Greg Tran   Consumer      Adelaide  South Australia
# 26594    CL-12565     Clay Ludtke   Consumer     Urbandale             Iowa
#
#        ...       Product ID         Category Sub-Category  \
# 26583  ...  OFF-SU-10003160  Office Supplies     Supplies
# 26584  ...  OFF-AR-10002145  Office Supplies          Art
# 26586  ...  OFF-EN-10000315  Office Supplies    Envelopes
# 26587  ...  OFF-BI-10004685  Office Supplies      Binders
# 26594  ...  OFF-AR-10000380  Office Supplies          Art
#
#                                           Product Name   Sales Quantity  \
# 26583                           Acme Ruler, High Speed  33.420        2
# 26584           Binney & Smith Sketch Pad, Fluorescent  95.160        2
# 26586          Jiffy Business Envelopes, Security-Tint  47.880        3
# 26587                             Acco Binder, Economy  40.905        3
# 26594  Hunt PowerHouse Electric Pencil Sharpener, Blue  75.960        2
#
#       Discount  Profit  Shipping Cost  Order Priority
# 26583      0.0   1.320           7.23            High
# 26584      0.0   4.740           7.23          Medium
# 26586      0.0   9.090           7.23            High
# 26587      0.1   9.495           7.23            High
# 26594      0.0  22.788           7.23          Medium
#
# [5 rows x 23 columns]

# %%
df_num=df_4.select_dtypes(include=[np.number])
df_num
# Out:
#        Row ID   Sales  Quantity  Discount   Profit  Shipping Cost
# 26583   10778  33.420         2       0.0   1.3200           7.23
# 26584   17129  95.160         2       0.0   4.7400           7.23
# 26586   21231  47.880         3       0.0   9.0900           7.23
# 26587   23945  40.905         3       0.1   9.4950           7.23
# 26594   31408  75.960         2       0.0  22.7880           7.23
# ...       ...     ...       ...       ...      ...            ...
# 38117   16829  49.380         2       0.0   3.9000           2.70
# 38120   21176  47.844         4       0.1  21.2040           2.70
# 38127   30914  30.660         2       0.0   8.8800           2.70
# 38128   32008  24.448         4       0.2   8.8624           2.70
# 38136   50407  35.760         2       0.0  12.1200           2.70
#
# [3953 rows x 6 columns]

# %%
df_cat=df_4.select_dtypes(include=["object"])
df_cat
# Out:
#               Order ID       Ship Mode Customer ID      Customer Name  \
# 26583  ES-2014-5617990     First Class    LW-16825     Laurel Workman
# 26584  ES-2014-3096832  Standard Class    BW-11065      Barry Weirich
# 26586    IN-2012-45951  Standard Class    JG-15115         Jack Garza
# 26587    IN-2012-40547     First Class    GT-14710          Greg Tran
# 26594   CA-2013-128867  Standard Class    CL-12565        Clay Ludtke
# ...                ...             ...         ...                ...
# 38117  ES-2013-1469005    Second Class    MC-17635     Matthew Clasen
# 38120    IN-2014-23621  Standard Class    GR-14560  Georgia Rosenberg
# 38127    IN-2013-80594  Standard Class    KA-16525     Kelly Andreada
# 38128   CA-2014-146136  Standard Class    AP-10915     Arthur Prichep
# 38136      IZ-2011-890  Standard Class     KC-6675    Kimberly Carter
#
#          Segment          City            State        Country Market  \
# 26583  Corporate  Schiltigheim           Alsace         France     EU
# 26584   Consumer       Catania           Sicily          Italy     EU
# 26586   Consumer        Bhopal   Madhya Pradesh          India   APAC
# 26587   Consumer      Adelaide  South Australia      Australia   APAC
# 26594   Consumer     Urbandale             Iowa  United States     US
# ...          ...           ...              ...            ...    ...
# 38117  Corporate        Modena   Emilia-Romagna          Italy     EU
# 38120  Corporate     Melbourne         Victoria      Australia   APAC
# 38127   Consumer  Christchurch       Canterbury    New Zealand   APAC
# 38128   Consumer    Palm Coast          Florida  United States     US
# 38136  Corporate         Mosul           Ninawa           Iraq   EMEA
#
#              Region        Product ID         Category Sub-Category  \
# 26583       Central   OFF-SU-10003160  Office Supplies     Supplies
# 26584         South   OFF-AR-10002145  Office Supplies          Art
# 26586  Central Asia   OFF-EN-10000315  Office Supplies    Envelopes
# 26587       Oceania   OFF-BI-10004685  Office Supplies      Binders
# 26594       Central   OFF-AR-10000380  Office Supplies          Art
# ...             ...               ...              ...          ...
# 38117         South   OFF-EN-10004051  Office Supplies    Envelopes
# 38120       Oceania   OFF-BI-10004553  Office Supplies      Binders
# 38127       Oceania   OFF-BI-10004185  Office Supplies      Binders
# 38128         South   OFF-EN-10001219  Office Supplies    Envelopes
# 38136          EMEA  OFF-STA-10001791  Office Supplies          Art
#
#                                           Product Name Order Priority
# 26583                           Acme Ruler, High Speed           High
# 26584           Binney & Smith Sketch Pad, Fluorescent         Medium
# 26586          Jiffy Business Envelopes, Security-Tint           High
# 26587                             Acco Binder, Economy           High
# 26594  Hunt PowerHouse Electric Pencil Sharpener, Blue         Medium
# ...                                                ...            ...
# 38117                  Ames Manila Envelope, Set of 50         Medium
# 38120                           Cardinal Binder, Clear         Medium
# 38127                         Cardinal Binder, Durable         Medium
# 38128     #10- 4 1/8" x 9 1/2" Security-Tint Envelopes           High
# 38136                Stanley Highlighters, Water Color         Medium
#
# [3953 rows x 15 columns]

# %%
df_num.drop(["Row ID"],axis=1,inplace=True)
df_num
# Out:
#         Sales  Quantity  Discount   Profit  Shipping Cost
# 26583  33.420         2       0.0   1.3200           7.23
# 26584  95.160         2       0.0   4.7400           7.23
# 26586  47.880         3       0.0   9.0900           7.23
# 26587  40.905         3       0.1   9.4950           7.23
# 26594  75.960         2       0.0  22.7880           7.23
# ...       ...       ...       ...      ...            ...
# 38117  49.380         2       0.0   3.9000           2.70
# 38120  47.844         4       0.1  21.2040           2.70
# 38127  30.660         2       0.0   8.8800           2.70
# 38128  24.448         4       0.2   8.8624           2.70
# 38136  35.760         2       0.0  12.1200           2.70
#
# [3953 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
le=LabelEncoder()
df_cat_e=df_cat.apply(le.fit_transform)

# %%
min_max=MinMaxScaler()
df_num_max=min_max.fit_transform(df_num)

# %%
df_cat_e
# Out:
#        Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  State  \
# 26583      1476          0          706            447        1  1229     19
# 26584      1359          3          183             70        0   282    497
# 26586      1773          3          544            337        0   176    319
# 26587      1758          0          468            310        0    10    506
# 26594       353          3          232            169        0  1390    246
# ...         ...        ...          ...            ...      ...   ...    ...
# 38117      1043          2          722            500        1   906    171
# 38120      2068          3          466            300        1   876    569
# 38127      2008          3          614            427        0   326    111
# 38128       560          3           67             60        0  1031    184
# 38136      2396          3          627            437        1   931    384
#
#        Country  Market  Region  Product ID  Category  Sub-Category  \
# 26583       35       4       3        2160         1            14
# 26584       51       4      10         462         1             2
# 26586       46       0       4         923         1             6
# 26587        4       0       9         826         1             3
# 26594      105       6       3         352         1             2
# ...        ...     ...     ...         ...       ...           ...
# 38117       51       4      10        1064         1             6
# 38120        4       0       9         822         1             3
# 38127       72       0       9         807         1             3
# 38128      105       6      10         949         1             6
# 38136       49       3       5        2004         1             2
#
#        Product Name  Order Priority
# 26583            79               1
# 26584           271               3
# 26586           739               1
# 26587            27               1
# 26594           697               3
# ...             ...             ...
# 38117           149               3
# 38120           333               3
# 38127           334               3
# 38128             1               1
# 38136          1116               3
#
# [3953 rows x 15 columns]

# %%
df_num_max
# Out:
# array([[0.13482217, 0.        , 0.        , 0.03594771, 1.        ],
#        [0.98593879, 0.        , 0.        , 0.12908497, 1.        ],
#        [0.33416046, 0.5       , 0.        , 0.24754902, 1.        ],
#        ...,
#        [0.09677419, 0.        , 0.        , 0.24183007, 0.        ],
#        [0.01113868, 1.        , 0.4       , 0.24135076, 0.        ],
#        [0.16708023, 0.        , 0.        , 0.33006536, 0.        ]])

# %%
df_num_max1=pd.DataFrame(df_num_max)

# %%
df_num_max1.head()
# Out:
#           0    1    2         3    4
# 0  0.134822  0.0  0.0  0.035948  1.0
# 1  0.985939  0.0  0.0  0.129085  1.0
# 2  0.334160  0.5  0.0  0.247549  1.0
# 3  0.238007  0.5  0.2  0.258578  1.0
# 4  0.721257  0.0  0.0  0.620588  1.0

# %%
df_cat_e.head()
# Out:
#        Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  State  \
# 26583      1476          0          706            447        1  1229     19
# 26584      1359          3          183             70        0   282    497
# 26586      1773          3          544            337        0   176    319
# 26587      1758          0          468            310        0    10    506
# 26594       353          3          232            169        0  1390    246
#
#        Country  Market  Region  Product ID  Category  Sub-Category  \
# 26583       35       4       3        2160         1            14
# 26584       51       4      10         462         1             2
# 26586       46       0       4         923         1             6
# 26587        4       0       9         826         1             3
# 26594      105       6       3         352         1             2
#
#        Product Name  Order Priority
# 26583            79               1
# 26584           271               3
# 26586           739               1
# 26587            27               1
# 26594           697               3

# %%
d1=df_cat_e.reset_index()

# %%
d1.head()
# Out:
#    index  Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  \
# 0  26583      1476          0          706            447        1  1229
# 1  26584      1359          3          183             70        0   282
# 2  26586      1773          3          544            337        0   176
# 3  26587      1758          0          468            310        0    10
# 4  26594       353          3          232            169        0  1390
#
#    State  Country  Market  Region  Product ID  Category  Sub-Category  \
# 0     19       35       4       3        2160         1            14
# 1    497       51       4      10         462         1             2
# 2    319       46       0       4         923         1             6
# 3    506        4       0       9         826         1             3
# 4    246      105       6       3         352         1             2
#
#    Product Name  Order Priority
# 0            79               1
# 1           271               3
# 2           739               1
# 3            27               1
# 4           697               3

# %%
d1.drop(["index"],axis=1,inplace=True)

# %%
df_final=pd.concat([df_num_max1,d1],axis=1)

# %%
df_final
# Out:
#              0    1    2         3    4  Order ID  Ship Mode  Customer ID  \
# 0     0.134822  0.0  0.0  0.035948  1.0      1476          0          706
# 1     0.985939  0.0  0.0  0.129085  1.0      1359          3          183
# 2     0.334160  0.5  0.0  0.247549  1.0      1773          3          544
# 3     0.238007  0.5  0.2  0.258578  1.0      1758          0          468
# 4     0.721257  0.0  0.0  0.620588  1.0       353          3          232
# ...        ...  ...  ...       ...  ...       ...        ...          ...
# 3948  0.354839  0.0  0.0  0.106209  0.0      1043          2          722
# 3949  0.333664  1.0  0.2  0.577451  0.0      2068          3          466
# 3950  0.096774  0.0  0.0  0.241830  0.0      2008          3          614
# 3951  0.011139  1.0  0.4  0.241351  0.0       560          3           67
# 3952  0.167080  0.0  0.0  0.330065  0.0      2396          3          627
#
#       Customer Name  Segment  City  State  Country  Market  Region  \
# 0               447        1  1229     19       35       4       3
# 1                70        0   282    497       51       4      10
# 2               337        0   176    319       46       0       4
# 3               310        0    10    506        4       0       9
# 4               169        0  1390    246      105       6       3
# ...             ...      ...   ...    ...      ...     ...     ...
# 3948            500        1   906    171       51       4      10
# 3949            300        1   876    569        4       0       9
# 3950            427        0   326    111       72       0       9
# 3951             60        0  1031    184      105       6      10
# 3952            437        1   931    384       49       3       5
#
#       Product ID  Category  Sub-Category  Product Name  Order Priority
# 0           2160         1            14            79               1
# 1            462         1             2           271               3
# 2            923         1             6           739               1
# 3            826         1             3            27               1
# 4            352         1             2           697               3
# ...          ...       ...           ...           ...             ...
# 3948        1064         1             6           149               3
# 3949         822         1             3           333               3
# 3950         807         1             3           334               3
# 3951         949         1             6             1               1
# 3952        2004         1             2          1116               3
#
# [3953 rows x 20 columns]

# %%
df_final.rename(columns={0:"Sales",1:"Quantity",2:"Discount",3:"Profit",4:"Shipping Cost"},inplace=True)

# %%
df_final.head()
# Out:
#       Sales  Quantity  Discount    Profit  Shipping Cost  Order ID  Ship Mode  \
# 0  0.134822       0.0       0.0  0.035948            1.0      1476          0
# 1  0.985939       0.0       0.0  0.129085            1.0      1359          3
# 2  0.334160       0.5       0.0  0.247549            1.0      1773          3
# 3  0.238007       0.5       0.2  0.258578            1.0      1758          0
# 4  0.721257       0.0       0.0  0.620588            1.0       353          3
#
#    Customer ID  Customer Name  Segment  City  State  Country  Market  Region  \
# 0          706            447        1  1229     19       35       4       3
# 1          183             70        0   282    497       51       4      10
# 2          544            337        0   176    319       46       0       4
# 3          468            310        0    10    506        4       0       9
# 4          232            169        0  1390    246      105       6       3
#
#    Product ID  Category  Sub-Category  Product Name  Order Priority
# 0        2160         1            14            79               1
# 1         462         1             2           271               3
# 2         923         1             6           739               1
# 3         826         1             3            27               1
# 4         352         1             2           697               3

# %%
df_final.isnull().sum()
# Out:
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Order Priority    0
# dtype: int64

# %%
x=df_final.drop("Sales",axis=1)
y=df_final["Sales"]

# %%
x
# Out:
#       Quantity  Discount    Profit  Shipping Cost  Order ID  Ship Mode  \
# 0          0.0       0.0  0.035948            1.0      1476          0
# 1          0.0       0.0  0.129085            1.0      1359          3
# 2          0.5       0.0  0.247549            1.0      1773          3
# 3          0.5       0.2  0.258578            1.0      1758          0
# 4          0.0       0.0  0.620588            1.0       353          3
# ...        ...       ...       ...            ...       ...        ...
# 3948       0.0       0.0  0.106209            0.0      1043          2
# 3949       1.0       0.2  0.577451            0.0      2068          3
# 3950       0.0       0.0  0.241830            0.0      2008          3
# 3951       1.0       0.4  0.241351            0.0       560          3
# 3952       0.0       0.0  0.330065            0.0      2396          3
#
#       Customer ID  Customer Name  Segment  City  State  Country  Market  \
# 0             706            447        1  1229     19       35       4
# 1             183             70        0   282    497       51       4
# 2             544            337        0   176    319       46       0
# 3             468            310        0    10    506        4       0
# 4             232            169        0  1390    246      105       6
# ...           ...            ...      ...   ...    ...      ...     ...
# 3948          722            500        1   906    171       51       4
# 3949          466            300        1   876    569        4       0
# 3950          614            427        0   326    111       72       0
# 3951           67             60        0  1031    184      105       6
# 3952          627            437        1   931    384       49       3
#
#       Region  Product ID  Category  Sub-Category  Product Name  Order Priority
# 0          3        2160         1            14            79               1
# 1         10         462         1             2           271               3
# 2          4         923         1             6           739               1
# 3          9         826         1             3            27               1
# 4          3         352         1             2           697               3
# ...      ...         ...       ...           ...           ...             ...
# 3948      10        1064         1             6           149               3
# 3949       9         822         1             3           333               3
# 3950       9         807         1             3           334               3
# 3951      10         949         1             6             1               1
# 3952       5        2004         1             2          1116               3
#
# [3953 rows x 19 columns]

# %%
y
# Out:
# 0       0.134822
# 1       0.985939
# 2       0.334160
# 3       0.238007
# 4       0.721257
#           ...
# 3948    0.354839
# 3949    0.333664
# 3950    0.096774
# 3951    0.011139
# 3952    0.167080
# Name: Sales, Length: 3953, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#       Quantity  Discount    Profit  Shipping Cost  Order ID  Ship Mode  \
# 2015       1.0      0.00  0.470588       0.379691      2834          3
# 3577       0.0      0.00  0.251634       0.064018      2284          3
# 3185       0.0      0.34  0.026438       0.139073      1721          3
# 111        0.5      0.00  0.688725       0.944812       935          3
# 2320       1.0      0.00  0.098039       0.315673      2421          3
# ...        ...       ...       ...            ...       ...        ...
# 1130       1.0      0.00  0.575163       0.607064      3417          2
# 1294       0.0      0.00  0.549020       0.560706      2290          3
# 860        0.0      0.40  0.197821       0.686534       301          1
# 3507       0.5      0.00  0.843137       0.075055      1203          3
# 3174       0.0      0.00  0.143791       0.141280      1772          3
#
#       Customer ID  Customer Name  Segment  City  State  Country  Market  \
# 2015          117             88        2   903    207       40       5
# 3577          559            358        0   554    218       48       3
# 3185          549            357        0   259    553      109       0
# 111           600            407        1  1275    172      104       4
# 2320           36             19        1  1437      0       54       3
# ...           ...            ...      ...   ...    ...      ...     ...
# 1130           59             52        1   674    280      103       3
# 1294          800            537        0    77     35       48       3
# 860           232            169        0   335    405      105       6
# 3507          665            445        2  1291    172      104       4
# 3174         1101            759        1  1242    204       21       0
#
#       Region  Product ID  Category  Sub-Category  Product Name  Order Priority
# 2015       3        1772         1            11           488               1
# 3577       5        1538         1             7           905               1
# 3185      11         467         1             2          1120               3
# 111        7         809         1             3           328               3
# 2320       5        1822         1            13          1062               3
# ...      ...         ...       ...           ...           ...             ...
# 1130       5        1325         1            14           547               3
# 1294       5          47         0             8           431               1
# 860        6        2289         2             0          1002               0
# 3507       7        1650         1            11           618               3
# 3174       8        2075         1            14            76               3
#
# [2767 rows x 19 columns]

# %%
y_train
# Out:
# 2015    0.301627
# 3577    0.074442
# 3185    0.254905
# 111     0.880066
# 2320    0.294458
#           ...
# 1130    0.559140
# 1294    0.370554
# 860     0.475214
# 3507    0.546319
# 3174    0.490488
# Name: Sales, Length: 2767, dtype: float64

# %%
x_test
# Out:
#       Quantity  Discount    Profit  Shipping Cost  Order ID  Ship Mode  \
# 3389       1.0      0.00  0.088235       0.094923      1680          3
# 2119       0.0      0.00  0.332244       0.357174      2488          3
# 2507       1.0      0.34  0.260000       0.271523      2106          3
# 70         0.5      0.00  0.122549       0.962472       820          0
# 2610       0.5      0.00  0.243464       0.253201      2826          3
# ...        ...       ...       ...            ...       ...        ...
# 565        0.0      0.00  0.277778       0.785872      2018          3
# 313        0.5      0.00  0.242647       0.869757      1649          0
# 601        1.0      0.00  0.470588       0.774834      3264          0
# 233        0.0      0.00  0.070763       0.900662       144          2
# 3370       0.5      0.00  0.752451       0.097130      1102          3
#
#       Customer ID  Customer Name  Segment  City  State  Country  Market  \
# 3389           47             45        1  1111    559       46       0
# 2119          651            440        0   217    520       15       5
# 2507          284            174        0  1485    590       69       0
# 70           1032            694        2   984    242       35       4
# 2610          812            547        0  1220    483       25       5
# ...           ...            ...      ...   ...    ...      ...     ...
# 565          1110            735        1  1034    327       72       0
# 313            44             13        0   128    245       21       0
# 601          1117            736        0   802    316       80       3
# 233           444            311        0   350    357      105       6
# 3370         1041            705        2   821    320       91       4
#
#       Region  Product ID  Category  Sub-Category  Product Name  Order Priority
# 3389       4        2183         1            14          1146               3
# 2119      10        1786         1            11           613               3
# 2507      11        1175         1             7          1169               3
# 70         3        1310         1             7          1160               3
# 2610       2         487         1             2           264               1
# ...      ...         ...       ...           ...           ...             ...
# 565        9        2051         1            14            87               3
# 313        8        1497         1             9           878               3
# 601        5         284         1             7           120               1
# 233        3        1929         1            13           529               3
# 3370      10         595         1             3          1240               3
#
# [1186 rows x 19 columns]

# %%
y_test
# Out:
# 3389    0.312655
# 2119    0.561897
# 2507    0.404566
# 70      0.453267
# 2610    0.497105
#           ...
# 565     0.959471
# 313     0.187758
# 601     0.557486
# 233     0.569617
# 3370    0.831679
# Name: Sales, Length: 1186, dtype: float64

# %%
import os
os.environ['GIT_PYTHON_REFRESH']='quiet'
os.environ['MLFLOW_TRACKING_URI']="file:///Users/sanja/Mlflow"

# %%
import mlflow

# %%
mlflow.set_experiment("globalstore-analysis")
mlflow.set_experiment_tag('store-tag','ex1')
# Out:
# 2025/02/03 09:27:44 INFO mlflow.tracking.fluent: Experiment with name 'globalstore-analysis' does not exist. Creating a new experiment.

# %%
with mlflow.start_run():    
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.metrics import r2_score
    
    # model object initialization
    RandFor=RandomForestRegressor(n_estimators=5000,max_depth=6)
    GBM=GradientBoostingRegressor(n_estimators=3000,max_depth=6,learning_rate=0.01,min_samples_split=5)
    rf_n_estimators=5000
    #logging parameters
    mlflow.log_param("n_estimators",rf_n_estimators)
    mlflow.log_param('rf_max_depth',6)
    mlflow.log_param('gbm_n_estimators',3000)
    mlflow.log_param('gbm_max_depth',6)
    mlflow.log_param('gbm_learning_rate',0.01)
    mlflow.log_param('gbm_minimum_samples_split',5)
    
    #training models
    rf=RandFor.fit(x_train,y_train)
    gbm=GBM.fit(x_train,y_train)
    
    #training scores
    training_score_rf=RandFor.score(x_train,y_train)
    training_score_gbm=GBM.score(x_train,y_train)
    
    #logging training score
    mlflow.log_metric("rf_training_score", training_score_rf)
    mlflow.log_metric("gbm_training_score",training_score_gbm)
    
    #value predictions
    y_pred_rf=rf.predict(x_test)
    y_pred_gbm=gbm.predict(x_test)
    
    #prediction evaluations
    testing_score_rf=r2_score(y_pred_rf,y_test)
    testing_score_gbm=r2_score(y_pred_gbm,y_test)
    
    #logging evaluation scores
    mlflow.log_metric("rf_training_score", testing_score_rf)
    mlflow.log_metric("gbm_training_score",testing_score_gbm)
    
    #logging models
    mlflow.sklearn.log_model(rf, "random-forest-model")
    mlflow.sklearn.log_model(gbm, "gradient-boosting-model")
# Out:
# 2025/02/03 09:32:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/03 09:32:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
import requests
import json


data = {'dataframe_records': x_test.values.tolist()}
headers = {"Content-Type": "application/json"}

response = requests.post("http://localhost:8004/invocations", data=json.dumps(data), headers=headers)
predictions = response.json()

print(predictions)
# Out:
# {'predictions': [0.306145930680119, 0.44074526452862317, 0.4070582274386494, 0.30634669682991506, 0.13458314017210266, 0.3986865949503116, 0.16180660078697323, 0.4035948811580055, 0.4240009950754845, 0.6068223579546876, 0.24102488584126758, 0.48044502884020784, 0.16509437254169815, 0.7022267409362077, 0.194359695211588, 0.6767235045761882, 0.31877115892313757, 0.6414097842180007, 0.13601730448261132, 0.48609057129079486, 0.27801778712113934, 0.14032804921562045, 0.6495898780237631, 0.6776433030958692, 0.1636190507086612, 0.5168442871731572, 0.31929488966827657, 0.3246705008793874, 0.25690285513652844, 0.13168489192893557, 0.1637382428607052, 0.16674280988267173, 0.4183568298924755, 0.148150573166702, 0.4382987674706352, 0.4172904402195275, 0.44457500800238486, 0.1303296419571518, 0.39917465262996504, 0.3719630915312864, 0.6187663501776121, 0.37642886603244874, 0.13882602592142035, 0.4100613597291474, 0.7847197050203288, 0.25500004272529203, 0.49214835300667453, 0.45053245155072763, 0.2717227518395136, 0.5426912461011809, 0.40688066888168367, 0.14302133489011618, 0.4182548777478689, 0.5125835676987139, 0.4462994111011123, 0.42497328617031344, 0.1354493034015809, 0.1368099430191154, 0.1551353694648409, 0.13655403857010762, 0.2127617965338251, 0.21504004710838012, 0.4722626858495482, 0.18033186890891756, 0.36838943745066405, 0.31719565439085184, 0.1764066668799433, 0.3136546558618963, 0.673947886137802, 0.7532218637077752, 0.38346160540275953, 0.28281384763019407, 0.1797501889596082, 0.42493328745138403, 0.4928329793527915, 0.15405617995453671, 0.36343983033359073, 0.21019409835058642, 0.3315237156637679, 0.5241174242900795, 0.2646969294159937, 0.2703518902254794, 0.46311717702965943, 0.4889778011418072, 0.17640582767141758, 0.7078329828828761, 0.3615800041315046, 0.1700665721210466, 0.3109790197136057, 0.21344745937968881, 0.6828606231415685, 0.5030397011677684, 0.18347622093308022, 0.13747635077030232, 0.5316494572271662, 0.17807873661701043, 0.30621291804905476, 0.3188387466643982, 0.45185654788066115, 0.1596842828219003, 0.42693128448461815, 0.340440252841738, 0.6943832565418877, 0.420174396548551, 0.23922360854918123, 0.6248627595971697, 0.25695905856652973, 0.7157632946288257, 0.13609292743510001, 0.25602714146651234, 0.44242879632116344, 0.28446259189356105, 0.45999606754492933, 0.42293950040854117, 0.6014856934903028, 0.5288304330733159, 0.1651720717762499, 0.28536502486789833, 0.2075321629198292, 0.7257865089462069, 0.27797231663329175, 0.23165436069137194, 0.13093319965144176, 0.15660551900929995, 0.6321929221552867, 0.28293997525678516, 0.6307201018582442, 0.2783388162899509, 0.19023444547932558, 0.7584468316246722, 0.600388759686644, 0.4462994691705939, 0.47529279402354613, 0.3445880459530291, 0.6000953934696167, 0.28070364026742056, 0.4631515254872128, 0.7607250931100159, 0.2538513262291821, 0.48796976168208483, 0.18906608451698326, 0.4827554495680593, 0.7586350227688479, 0.5723085920133062, 0.14378390029982646, 0.5683884489006509, 0.4220449818099556, 0.347307234003331, 0.15946998638165455, 0.2702745832263301, 0.5760863784221211, 0.3415352866878561, 0.4490702036755646, 0.3395976532250612, 0.49832363631128873, 0.512561009623879, 0.30634322011955334, 0.20673322176996056, 0.3418770536882817, 0.4229495366103237, 0.6817484665711894, 0.13701417388482434, 0.41219523212437564, 0.691756302640599, 0.21249855131838408, 0.41899931177592936, 0.5665901103379635, 0.38842707023965173, 0.4688327744706292, 0.4562055110515454, 0.320264481394743, 0.1604531026156549, 0.6814609923875269, 0.21520224862350143, 0.2628947071679507, 0.5900716934696254, 0.6657653394398846, 0.36357646685468115, 0.40188043582146105, 0.804809548625448, 0.1511870736959308, 0.15703958798188675, 0.18864173007627325, 0.3141550948857049, 0.15635741259422276, 0.19688386744098232, 0.5924385106487225, 0.19205510859258235, 0.335385867058155, 0.5059001916056415, 0.19087933043507202, 0.2053584206534586, 0.6452702868110802, 0.6051670419485139, 0.713821178653245, 0.69903018640 ...

# %%
# !mlflow models serve -p 8004 -m runs:/481311154b784132a4ccdaf9932eea31/random-forest-model  --no-conda
